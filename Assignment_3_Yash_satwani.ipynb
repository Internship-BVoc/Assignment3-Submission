# %% [markdown]
# #This Assignment is sumbitted by Yash Satwani

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset_model.csv',sep=',')
pd.set_option('display.max_rows',df.shape[0]+1)
df
# Out:
#       Loan_ID  Gender Married  ... Credit_History Property_Area Loan_Status
# 0    LP001002    Male      No  ...            1.0         Urban           Y
# 1    LP001003    Male     Yes  ...            1.0         Rural           N
# 2    LP001005    Male     Yes  ...            1.0         Urban           Y
# 3    LP001006    Male     Yes  ...            1.0         Urban           Y
# 4    LP001008    Male      No  ...            1.0         Urban           Y
# 5    LP001011    Male     Yes  ...            1.0         Urban           Y
# 6    LP001013    Male     Yes  ...            1.0         Urban           Y
# 7    LP001014    Male     Yes  ...            0.0     Semiurban           N
# 8    LP001018    Male     Yes  ...            1.0         Urban           Y
# 9    LP001020    Male     Yes  ...            1.0     Semiurban           N
# 10   LP001024    Male     Yes  ...            1.0         Urban           Y
# ...

# %%
print(df.shape)
# Out:
# (614, 13)

# %%
#1. Idenitfy & Remove the field that is providing only unique information about records .Capture it in another dataframe
df_unique_identity = df['Loan_ID']
df.drop(['Loan_ID'],axis=1,inplace=True)
df.head()
# Out:
#   Gender Married Dependents  ... Credit_History Property_Area  Loan_Status
# 0   Male      No          0  ...            1.0         Urban            Y
# 1   Male     Yes          1  ...            1.0         Rural            N
# 2   Male     Yes          0  ...            1.0         Urban            Y
# 3   Male     Yes          0  ...            1.0         Urban            Y
# 4   Male      No          0  ...            1.0         Urban            Y
#
# [5 rows x 12 columns]

# %%
#2. Identifying Continous & Categorical Columns
print(df.columns)
#categorical
print("The unique elements in Gender field are", df['Gender'].unique())
print("The unique elements in Married field are", df['Married'].unique())
print("The unique elements in Dependents field are", df['Dependents'].unique())
print("The unique elements in Education field are", df['Education'].unique())
print("The unique elements in Self_employed field are", df['Self_Employed'].unique())
print("The unique elements in Loan_Amount_Term	 field are", df['Loan_Amount_Term'].unique())
print("The unique elements in Credit_History field are", df['Credit_History'].unique())
print("The unique elements in Property_Area field are", df['Property_Area'].unique())
print("The unique elements in Loan_Status field are", df['Loan_Status'].unique())
#continious
print("The length of different categorial field ApplicantIncome is", len(df['ApplicantIncome'].unique()))
print("The length of different categorial field CoapplicantIncome is", len(df['CoapplicantIncome'].unique()))
print("The length of different categorial field LoanAmount is", len(df['LoanAmount'].unique()))
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')
# The unique elements in Gender field are ['Male' 'Female' nan]
# The unique elements in Married field are ['No' 'Yes' nan]
# The unique elements in Dependents field are ['0' '1' '2' '3+' nan]
# The unique elements in Education field are ['Graduate' 'Not Graduate']
# The unique elements in Self_employed field are ['No' 'Yes' nan]
# The unique elements in Loan_Amount_Term	 field are [360. 120. 240.  nan 180.  60. 300. 480.  36.  84.  12.]
# The unique elements in Credit_History field are [ 1.  0. nan]
# The unique elements in Property_Area field are ['Urban' 'Rural' 'Semiurban']
# The unique elements in Loan_Status field are ['Y' 'N']
# The length of different categorial field ApplicantIncome is 505
# ...

# %% [markdown]
# #3. Performing Uni-variate Analysis with Plots.Record your Observations

# %%
df['Gender'].value_counts().plot.bar()

# %% [markdown]
# #Observation
#
# -There are more number of males than females upplying for loan.

# %%
df['Married'].value_counts().plot.bar()

# %% [markdown]
# #Observation
#
# -There are more number of Married people upplying for loan.

# %%
df['Dependents'].value_counts().plot.bar()

# %% [markdown]
# #Observations
#
# 1. The dependents categorized as 0 are highest.
# 2. The dependents categorized as 1 and 2 are equal in number.
# 3. The dependents categorized as 3+ are smallest in number.

# %%
df['Education'].value_counts().plot.bar()

# %% [markdown]
# #Observation
#
# -The  graduates are highets applyers of loan.

# %%
df['Self_Employed'].value_counts().plot.bar()

# %% [markdown]
# #Observation
#
# -The no. of loan applications are from people who are not self_employed.

# %%
df['Loan_Amount_Term'].value_counts().plot.bar()

# %% [markdown]
# #Observation
#
# -There are more than 500 applications for loan for a term of 360.
# -rest all application for loan, duration lies from 180 to 12 .

# %%
df['Credit_History'].value_counts().plot.bar()

# %% [markdown]
# #Observation
#
# -The no. of apllication from people who has a credit history is more than 400.

# %%
df['Property_Area'].value_counts().plot.bar()

# %% [markdown]
# #Observations
#
# - There are more than 200 people who have applied for loan against property_area "semiurban". which is the highest.

# %%
df['Loan_Status'].value_counts().plot.bar()

# %% [markdown]
# #Observations
#
# - There are more than 400 applicants whose loan has been approved.
# - The no of applicants whose loan has been rejectd is less than 200.

# %%
df.hist(figsize=[17,6])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f668604d588>,
# ...
#       dtype=object)

# %% [markdown]
# #Observation
#
# - The no. of applicants having income between 0 to 8000 are highest in number.
# - The no. of coapplicants having income between 0 to 5000 are highest in number.

# %% [markdown]
# #4. Perform Bi-variate Analysis among all Independent variables.Draw appropriate Plots , mention observations

# %%
#compare education with regards to gender
fig1 = sns.FacetGrid(df,col='Gender',height=5, aspect=2)
fig1.map(plt.hist,"Education")

# %% [markdown]
# #Observations
# - The number of male graduates are more than ungraduate male.
# - there are more male graduates than female graduates.
# - The number of female graduates are more than not graduate.

# %%
#compare gender with regards to self_employed
fig2 = sns.FacetGrid(df,col='Self_Employed',height=5, aspect=2)
fig2.map(plt.hist,"Gender")

# %% [markdown]
# #Observations
# - The number of male s are more that not self employe than females.
# - there are more male that are not self employed than female .
# - The number of female self employed  are less  than male.

# %%
#compare gender with regards to Property_Area
fig3 = sns.FacetGrid(df,col='Property_Area',height=7, aspect=1)
fig3.map(plt.hist,"Gender")

# %%
fig4 = sns.FacetGrid(df,col='Gender',height=5, aspect=1)
fig4.map(plt.hist,"ApplicantIncome")

# %% [markdown]
# #Observation
# - The male applicant income is more than female applicants.
# - Most of the female applicants income lie between 0 to 10000.

# %% [markdown]
# #5. Perform Bi-variate Analysis between Target Variable and each Independent variable. Use suitable plot , mention observations,trends etc

# %%
for a in df.drop('Loan_Status',axis=1).columns:
  f= sns.FacetGrid(df,col='Loan_Status',height=5, aspect=1)
  f.map(plt.hist,a)

# %% [markdown]
# #Observations
#
# - The no. of approved male loan applicants are more than female.
# -The no. of unapproved male applicants are more than approved female applicants and unapproved female applicants.
#
# - The no. of approved non mrried  loan applicants are more than unmarried.
# -The no. of approved married applicants are more than unapproved married applicants and unapproved unmarried applicants.
#
# - The no of approved loan with dependents labeled as 1 are the highest in no.
# - The no of dissapproved loan with dependents labeled as 3+ are the highes.
# - The no. of approved loans is highest for graduates
# - The no. of approved loans is highest for people who are not self employed.
# - The no. of unapproved loans are highest for people who are not self employed
#
# - The loan is approved for most people having income between 0 to 8000.
#
# - The no of approved loans for coapplicants income ranging between 0 to 10000 is the highest.
# - The no of approved loan for loan amount between 100 to 150 is the highest.
# - The no of approved loan for loan tern  between 350 to 380 is the highest.
# - The no of approved loan for credit history  between 0.8 to 1.0 is the highest.
# - The no of approved loan for loan amount between 100 to 150 is the highest.
# - The no of approved loan for semi urban property area the highest followed by rural and than urban.

# %% [markdown]
# #6. How is the class distribution (Y/N) in Label(Target) Variable ?

# %%
df['Loan_Status'].value_counts().plot.bar()

# %% [markdown]
# #observation
# - the no of 'y' in the target variable are more tha 400 ,and the no. of 'n' are more than 150 and less than 200. 'y' being the highest in the class distribution.

# %%
#7. Identify the Independent Variables that have missing values.
df.drop("Loan_Status",axis=1).isna().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# dtype: int64

# %%
#Visualising the independent variables having null values and how much in number 
sns.heatmap(df.drop("Loan_Status",axis=1).isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.head()
# Out:
#   Gender Married Dependents  ... Credit_History Property_Area  Loan_Status
# 0   Male      No          0  ...            1.0         Urban            Y
# 1   Male     Yes          1  ...            1.0         Rural            N
# 2   Male     Yes          0  ...            1.0         Urban            Y
# 3   Male     Yes          0  ...            1.0         Urban            Y
# 4   Male      No          0  ...            1.0         Urban            Y
#
# [5 rows x 12 columns]

# %% [markdown]
# #8. Handle missing values appropriately , explain the technique applied for each case

# %%
#replacing the missing values in  categorical data with mode and numerical with median.
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].median())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].median())
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0],inplace=True)
#replacing the missing values in  continous  with mean.
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df.drop('Dependents',axis=1,inplace=True)
sns.heatmap(df.drop("Loan_Status",axis=1).isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
#9. Identify the Outliers in each Independent Variable.Distribute the data in each field using Quartile bins (0-25%,25%-50%,50%-75%,75%-100% iles)
print(df['ApplicantIncome'].describe())
print(df['CoapplicantIncome'].describe())
print(df['LoanAmount'].describe())
df['ApplicantIncome'].hist(bins=100)
df['CoapplicantIncome'].hist(bins=100)
df['LoanAmount'].hist(bins=100)
# Out:
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64
# count      614.000000
# mean      1621.245798
# std       2926.248369
# min          0.000000
# 25%          0.000000
# 50%       1188.500000
# 75%       2297.250000
# max      41667.000000
# Name: CoapplicantIncome, dtype: float64
# count    614.000000
# mean     146.412162
# std       84.037468
# min        9.000000
# 25%      100.250000
# 50%      129.000000
# 75%      164.750000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %%
#10.Use Box-Plot chart to represent the Outliers for each Independent Variable
df.boxplot(column=['ApplicantIncome'])

# %%
df.boxplot(column=['LoanAmount'])

# %%
df.boxplot(column=['CoapplicantIncome'])

# %%
#11. Perform treatment of these Outliers using appropriate techniqies.Explain your approach
#by droping the outlier in dataset
df.drop(df.loc[df['CoapplicantIncome']==41667.000000].index, inplace=True)
df.drop(df.loc[df['ApplicantIncome']==81000.000000].index, inplace=True)
df.drop(df.loc[df['LoanAmount']==81000.000000].index, inplace=True)

# %%
#Perform Label Encoding on Target Variable (Loan_Status).
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_le = df.copy()
df_le['Loan_Status'] = le.fit_transform(df_le['Loan_Status'])
df_le.head()
# Out:
#   Gender Married     Education  ... Credit_History  Property_Area  Loan_Status
# 0   Male      No      Graduate  ...            1.0          Urban            1
# 1   Male     Yes      Graduate  ...            1.0          Rural            0
# 2   Male     Yes      Graduate  ...            1.0          Urban            1
# 3   Male     Yes  Not Graduate  ...            1.0          Urban            1
# 4   Male      No      Graduate  ...            1.0          Urban            1
#
# [5 rows x 11 columns]

# %%
#Perform Label Encoding on Categorical Independent Variables.
df_le.drop('Married',axis=1,inplace=True)
df_le['Gender'] = le.fit_transform(df_le['Gender'])
df_le['Education'] = le.fit_transform(df_le['Education'])
df_le['Self_Employed'] = le.fit_transform(df_le['Self_Employed'])
df_le['Credit_History'] = le.fit_transform(df_le['Credit_History'])
df_le['Property_Area'] = le.fit_transform(df_le['Property_Area'])
df_le.head()
# Out:
#    Gender  Education  Self_Employed  ...  Credit_History  Property_Area  Loan_Status
# 0       1          0              0  ...               1              2            1
# 1       1          0              0  ...               1              0            0
# 2       1          0              1  ...               1              2            1
# 3       1          1              0  ...               1              2            1
# 4       1          0              0  ...               1              2            1
#
# [5 rows x 10 columns]

# %%
#What is the shape of dataframe post Categorical Encoding ?
df_le.shape
# Out:
# (612, 10)

# %%
#Carry out Correlation analysis on this dataframe. Plot using HeatMap
corr = df_le.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(10, 10))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
svm = sns.heatmap(corr, mask=mask, cmap=cmap, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5})
figure = svm.get_figure()

# %% [markdown]
# Strong Correlation
#
# - ApplicantIncome, LoanAmount
# - Credit_history, Loan_Status
# - LoanAmount, Education
# - ApplicantIncome, Education

# %%
#Perform One Hot Encoding on Categorical Independent Variables.
df_oh =df.copy()
num_cols = df._get_numeric_data().columns
for i in list(set(df.columns) - set(num_cols)): 
  df_oh = pd.get_dummies(df_oh, columns=[i], prefix=[i] )
df_oh
# Out:
#      ApplicantIncome  ...  Education_Not Graduate
# 0               5849  ...                       0
# 1               4583  ...                       0
# 2               3000  ...                       0
# 3               2583  ...                       1
# 4               6000  ...                       0
# 5               5417  ...                       0
# 6               2333  ...                       1
# 7               3036  ...                       0
# 8               4006  ...                       0
# 9              12841  ...                       0
# 10              3200  ...                       0
# 11              2500  ...                       0
# 12              3073  ...                       0
# 13              1853  ...                       0
# 14              1299  ...                       0
# 15              4950  ...                       0
# 16              3596  ...                       1
# 17              3510  ...                       0
# ...

# %%
#What is the shape of dataframe post OHE Encoding ?
df_oh.shape
# Out:
# (612, 18)

# %%
#Carry out Correlation analysis on this dataframe. Plot using HeatMap
corel = df_oh.corr()
mask = np.zeros_like(corel, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
svm = sns.heatmap(corel, mask=mask, cmap=cmap, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5})
figure = svm.get_figure()

# %% [markdown]
# #Identify the variables that have strong correlation using OHE ( Correlation Coefficient > 0.5 or <0.5)
# - Strong Relations
# - Married_0, Married_1
# - Gender_0, Gender_1
# - Education_0, Education_1
# - Self_Employed_0, Self_Employed_1
# - LoanAmount, ApplicantIncome
# - Gender_0, Married_1
# - Gender_1, Married_1
# - Gender_0, Married_0
# - Gender_1, Married_0
# - Property_Area_1, Property_Area_2
